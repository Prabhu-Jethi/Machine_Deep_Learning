# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import joblib


from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score, roc_auc_score


from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
df = pd.read_csv(r"D:\Python\ML\30_DAYS_ML_DL\Project_1\data\processed\loan_processed_data.csv")
df
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti   fico  \
# 0               1.0    0.1189       829.10       11.350407  19.48  737.0
# 1               1.0    0.1071       228.22       11.082143  14.29  707.0
# 2               1.0    0.1357       366.86       10.373491  11.63  682.0
# 3               1.0    0.1008       162.34       11.350407   8.10  712.0
# 4               1.0    0.1426       102.92       11.299732  14.97  667.0
# ...             ...       ...          ...             ...    ...    ...
# 9573            0.0    0.1461       344.76       12.180755  10.39  672.0
# 9574            0.0    0.1253       257.70       11.141862   0.21  722.0
# 9575            0.0    0.1071        97.81       10.596635  13.09  687.0
# 9576            0.0    0.1600       351.58       10.819778  19.18  692.0
# 9577            0.0    0.1392       853.43       11.264464  16.28  732.0
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  ...  \
# 0           5639.958333    28854.0        52.1             0.0  ...
# 1           2760.000000    33623.0        76.7             0.0  ...
# 2           4710.000000     3511.0        25.6             1.0  ...
# 3           2699.958333    33667.0        73.2             1.0  ...
# 4           4066.000000     4740.0        39.5             0.0  ...
# ...                 ...        ...         ...             ...  ...
# 9573       10474.000000   215372.0        82.1             2.0  ...
# 9574        4380.000000      184.0         1.1             5.0  ...
# 9575        3450.041667    10036.0        82.9             8.0  ...
# 9576        1800.000000        0.0         3.2             5.0  ...
# 9577        4740.000000    37879.0        57.0             6.0  ...
#
#       purpose_major_purchase  purpose_small_business  debt_income_ratio  \
# 0                      False                   False          73.045842
# 1                      False                   False          20.593491
# 2                      False                   False          35.365143
# 3                      False                   False          14.302571
# 4                      False                   False           9.108180
# ...                      ...                     ...                ...
# 9573                   False                   False          28.303665
# 9574                   False                   False          23.128989
# 9575                   False                   False           9.230289
# 9576                   False                   False          32.494196
# 9577                   False                   False          75.763036
#
#       many_inquiries  has_delinquency  has_public_record  fico_category_fair  \
# 0                  0                0                  0               False
# 1                  0                0                  0               False
# 2                  0                0                  0               False
# 3                  0                0                  0               False
# 4                  0                1                  0                True
# ...              ...              ...                ...                 ...
# 9573               0                0                  0               False
# 9574               1                0                  0               False
# 9575               1                0                  0               False
# 9576               1                0                  0               False
# 9577               1                0                  0               False
#
#       fico_category_good  fico_category_very good  fico_category_excellent
# 0                   True                    False                    False
# 1                   True                    False                    False
# 2                   True                    False                    False
# 3                   True                    False                    False
# 4                  False                    False                    False
# ...                  ...                      ...                      ...
# 9573                True                    False                    False
# 9574                True                    False                    False
# 9575                True                    False                    False
# 9576                True                    False                    False
# 9577                True                    False                    False
#
# [9578 rows x 27 columns]

# %%
X = df.drop('not.fully.paid', axis=1)
y = df['not.fully.paid']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7183, 26)
# (2395, 26)
# (7183,)
# (2395,)

# %% [markdown]
# ##### Training Multiple models

# %%
lr_pipe = Pipeline([
    ('sc', StandardScaler()),
    ('lr', LogisticRegression(
        max_iter=1000,
        class_weight='balanced'
    ))
])
lr_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('sc', StandardScaler()),
#                 ('lr',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
lr_cv = cross_val_score(
    lr_pipe,
    X_train,
    y_train, 
    cv=5,
    scoring='roc_auc'
)
### Train accuracy
train_ac = lr_pipe.score(X_train, y_train)
print("\nTraining-accuracy:\n", train_ac)
print("\nLogistic_Regression_CV:")
print(lr_cv.mean())
print(lr_cv.std())
# Out:
# Training-accuracy:
#  0.642767645830433
#
# Logistic_Regression_CV:
# 0.6792011180723307
# 0.014425781340459319

# %%
tree_pipe = Pipeline([
    ('dt', DecisionTreeClassifier(
        max_depth=6,
        min_samples_leaf=6,
        min_samples_split=4,
        random_state=42,
        class_weight='balanced'
    ))
])
tree_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('dt',
#                  DecisionTreeClassifier(class_weight='balanced', max_depth=6,
#                                         min_samples_leaf=6, min_samples_split=4,
#                                         random_state=42))])

# %%
dt_cv = cross_val_score(
    tree_pipe,
    X_train,
    y_train,
    cv=5,
    scoring='roc_auc'
)
### Train vs test accuracy
train_ac = tree_pipe.score(X_train, y_train)
print("\nTraining-accuracy:\n", train_ac)
print("\nDecisionTree CV:\n")
print(dt_cv.mean())
print(dt_cv.std())
# Out:
# Training-accuracy:
#  0.6619796742308228
#
# DecisionTree CV:
#
# 0.6237788782633666
# 0.014520845339404181

# %%
rf_pipe = Pipeline([
    ('rf', RandomForestClassifier(
        n_estimators=200,
        max_depth=6,
        min_samples_split=4,
        min_samples_leaf=6,
        random_state=42,
        class_weight='balanced'
    ))
])
rf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('rf',
#                  RandomForestClassifier(class_weight='balanced', max_depth=6,
#                                         min_samples_leaf=6, min_samples_split=4,
#                                         n_estimators=200, random_state=42))])

# %%
rf_cv = cross_val_score(
    rf_pipe,
    X_train,
    y_train,
    cv=5,
    scoring='roc_auc',
)
### Train vs test accuracy
train_ac = rf_pipe.score(X_train, y_train)
print("\nTraining-accuracy:\n", train_ac)
print("\nRandomForest CV:\n")
print(rf_cv.mean())
print(rf_cv.std())
# Out:
# Training-accuracy:
#  0.7095920924404845
#
# RandomForest CV:
#
# 0.6676374727350245
# 0.012076113453411436

# %%
xgb_pipe = Pipeline([
    ('xgb', XGBClassifier(
        max_depth=4,
        n_estimators=200,
        eval_metric='logloss',
        random_state=42,
        learning_rate=0.03,
        class_weight='score_pos_weight'
    ))
])
xgb_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('xgb',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                class_weight='score_pos_weight',
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=True, eval_metric='logloss',
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.03,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=4, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=200, n_jobs=None, ...))])

# %%
xgb_cv = cross_val_score(
    xgb_pipe,
    X_train,
    y_train,
    cv=5,
    scoring='roc_auc'
)
### Train vs test accuracy
train_ac = xgb_pipe.score(X_train, y_train)
print("\nTraining-accuracy:\n", train_ac)
print("\nXgboost CV:\n")
print(xgb_cv.mean())
print(xgb_cv.std())
# Out:
# Training-accuracy:
#  0.8504803007100098
#
# Xgboost CV:
#
# 0.6705801214381247
# 0.01269023371957016

# %%
def evaluate(model, X_test, y_test):
    pred = model.predict(X_test)
    prob = model.predict_proba(X_test)[:,1]

    return {
        "Accuracy": accuracy_score(y_test, pred),
        "Precision": precision_score(y_test, pred),
        "Recall": recall_score(y_test, pred),
        "F1 Score": f1_score(y_test, pred),
        "ROC-AUC": roc_auc_score(y_test, prob)
    }
lr_result = evaluate(lr_pipe, X_test, y_test)
rf_result = evaluate(rf_pipe, X_test, y_test)
dt_result = evaluate(tree_pipe, X_test, y_test)
xgb_result = evaluate(xgb_pipe, X_test, y_test)

# %%
comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "XGBoost"
    ],
    "Accuracy": [
        lr_result["Accuracy"],
        dt_result["Accuracy"],
        rf_result["Accuracy"],
        xgb_result["Accuracy"]
    ],
    "Precision": [
        lr_result["Precision"],
        dt_result["Precision"],
        rf_result["Precision"],
        xgb_result["Precision"]
    ],
    "Recall": [
        lr_result["Recall"],
        dt_result["Recall"],
        rf_result["Recall"],
        xgb_result["Recall"]
    ],
    "F1 Score": [
        lr_result["F1 Score"],
        dt_result["F1 Score"],
        rf_result["F1 Score"],
        xgb_result["F1 Score"]
    ],
    "ROC-AUC": [
        lr_result["ROC-AUC"],
        dt_result["ROC-AUC"],
        rf_result["ROC-AUC"],
        xgb_result["ROC-AUC"]
    ],
    "CV ROC-AUC (Mean)": [
        lr_cv.mean(),
        dt_cv.mean(),
        rf_cv.mean(),
        xgb_cv.mean()
    ],
    "CV Std": [
        lr_cv.std(),
        dt_cv.std(),
        rf_cv.std(),
        xgb_cv.std()
    ]
    })

comparison = comparison.sort_values(by="CV ROC-AUC (Mean)", ascending=False)
print("\nComparision_between_metrics_of_models:\n", comparison)
# Out:
# Comparision_between_metrics_of_models:
#                   Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC  \
# 0  Logistic Regression  0.643841   0.239468  0.563969  0.336187  0.674601
# 3              XGBoost  0.838413   0.375000  0.015666  0.030075  0.657816
# 2        Random Forest  0.682255   0.256443  0.519582  0.343399  0.663228
# 1        Decision Tree  0.625052   0.222222  0.537859  0.314504  0.612253
#
#    CV ROC-AUC (Mean)    CV Std
# 0           0.679201  0.014426
# 3           0.670580  0.012690
# 2           0.667637  0.012076
# 1           0.623779  0.014521

# %%
params = {
    'lr__max_iter': [1000, 2000, 3000]
}
grid = GridSearchCV(
    lr_pipe,
    param_grid=params,
    cv=5,
    scoring='roc_auc'
)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('sc', StandardScaler()),
#                                        ('lr',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=1000))]),
#              param_grid={'lr__max_iter': [1000, 2000, 3000]},
#              scoring='roc_auc')

# %%
best_model = grid.best_estimator_
best_model
# Out:
# Pipeline(steps=[('sc', StandardScaler()),
#                 ('lr',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
pred = best_model.predict(X_test)
pred
# Out:
# array([1., 1., 1., ..., 1., 0., 0.], shape=(2395,))

# %%
joblib.dump(lr_pipe, "../models/logisticregression.pkl")
# Out:
# ['../models/logisticregression.pkl']
